# %% [markdown]
# ###SQL in Pandas
#
# This notebook teaches the essential functions necessary to access and run SQL databases from within the Python-Pandas framework. For the process we will be using SQLite3, which is a database management system. However, unlike others, SQLite3 is not a separate process that is accessed from the client application, but an integral part of it.

# %%
import pandas as pd

# %%
import sqlite3

# %%
# %cd /home/ubuntu/DSE200/data/SQL/
# !ls
# Out:
# /home/ubuntu/DSE200/data/SQL
# usa_lat_long.csv

# %% [markdown]
# ###Reading a dataset into a dataframe
#
# For this exercise we will create a saple dataframe data_df by reading the csv file - usa_lat_long.csv using the comand read_csv

# %%
data_df = pd.read_csv('usa_lat_long.csv')
data_df
# Out:
#    State country   latitude   longitude
# 0     AE     USA  46.891090  -96.806283
# 1     AG     USA  35.147252 -103.577749
# 2     AK     USA  64.200841 -149.493673
# 3     AL     USA  32.318231  -86.902298
# 4     AR     USA  35.201050  -91.831833
# 5     AZ     USA  34.048928 -111.093731
# 6      C     USA  37.090240  -95.712891
# 7     CA     USA  36.778261 -119.417932
# 8     CO     USA  39.550051 -105.782067
# 9     CT     USA  41.603221  -73.087749
# 10    DC     USA  38.905985  -77.033418
# 11    DE     USA  38.910832  -75.527670
# 12    FL     USA  27.664827  -81.515754
# 13    GA     USA  32.157435  -82.907123
# 14    GT     USA  34.024545 -118.407284
# 15    GU     USA  29.526659  -97.936337
# 16    HI     USA  19.896766 -155.582782
# 17    IA     USA  41.878003  -93.097702
# 18    ID     USA  44.068202 -114.742041
# 19    IL     USA  40.633125  -89.398528
# 20    IN     USA  40.267194  -86.134902
# 21    KS     USA  39.011902  -98.484246
# 22    KY     USA  37.839333  -84.270018
# 23    LA     USA  31.244823  -92.145025
# 24    MA     USA  42.407211  -71.382437
# 25    MC     USA  42.467206  -71.287421
# 26    MD     USA  39.045755  -76.641271
# 27    ME     USA  45.253783  -69.445469
# 28    MI     USA  44.314844  -85.602364
# 29    MN     USA  46.729553  -94.685900
# ..   ...     ...        ...         ...
# 32    MT     USA  46.879682 -110.362566
# 33    NC     USA  35.759573  -79.019300
# 34    ND     USA  47.551493 -101.002012
# 35    NE     USA  41.492537  -99.901813
# 36    NH     USA  43.193852  -71.572395
# 37    NJ     USA  40.058324  -74.405661
# 38    NM     USA  34.519940 -105.870090
# 39    NV     USA  38.802610 -116.419389
# 40    NY     USA  40.714353  -74.005973
# 41    OH     USA  40.417287  -82.907123
# 42    OK     USA  35.007752  -97.092877
# 43    ON     USA  51.253775  -85.323214
# 44    OR     USA  43.804133 -120.554201
# 45    PA     USA  41.203322  -77.194525
# 46    PR     USA  39.002556  -94.349165
# 47    QC     USA  52.939916  -73.549136
# 48    RI     USA  41.580095  -71.477429
# 49    SC     USA  33.836081  -81.163725
# 50    SD     USA  43.969515  -99.901813
# 51    SV     USA  39.734785  -84.170385
# 52    TN     USA  35.517491  -86.580447
# 53    TX     USA  31.968599  -99.901813
# 54    UT     USA  39.320980 -111.093731
# 55    VA     USA  37.431573  -78.656894
# 56    VI     USA  36.559581  -96.159031
# 57    VT     USA  44.558803  -72.577842
# 58    WA     USA  47.751074 -120.740139
# 59    WI     USA  43.784440  -88.787868
# 60    WV     USA  38.597626  -80.454903
# 61    WY     USA  43.075968 -107.290284
#
# [62 rows x 4 columns]

# %% [markdown]
# ###Writing Dataframes
#
# We can insert the above dataframe data_df into a sql database by inbuilt sql functions write_frame
#
# Pandas has a write_frame function in pd.io.sql which creates a database table from a dataframe.
#
# To connect to a database we use sqlite3.connect function. The resultig variable con as shown below is passed everytimme a sql query is run via pandas on an sql database

# %%
con = sqlite3.connect("data_db.sqlite")

# %%
data_df.to_sql("data", con, if_exists='replace')

# %% [markdown]
# ### Reading data from SQL databases
#
# You can read data from a SQL database using the pd.read_sql function. read_sql will automatically convert SQL column names to DataFrame column names. read_sql takes 2 arguments: a SELECT statement, and a database connection object. This is great because it means you can read from any kind of SQL database -- it doesn't matter if it's MySQL, SQLite, PostgreSQL, or something else.

# %%
df = pd.read_sql("SELECT * from data LIMIT 3", con)
df
# Out:
#    index State country   latitude   longitude
# 0      0    AE     USA  46.891090  -96.806283
# 1      1    AG     USA  35.147252 -103.577749
# 2      2    AK     USA  64.200841 -149.493673

# %% [markdown]
# read_sql doesn't automatically set the primary key (id) to be the index of the dataframe. You can make it do that by adding an index_col argument to read_sql.

# %%
df = pd.read_sql("SELECT * from data LIMIT 3", con, index_col='State')
df
# Out:
#        index country   latitude   longitude
# State
# AE         0     USA  46.891090  -96.806283
# AG         1     USA  35.147252 -103.577749
# AK         2     USA  64.200841 -149.493673

# %% [markdown]
# You can now run many different sql queries on this dataset through the pandas framework. This is particularly helpful for those who are used to sql and want to use the same queries in pandas
#
# For example we can use sql query to fetch a row based on the values in a particular column

# %%
df = pd.read_sql("SELECT * from data WHERE longitude<-110",con)
df
# Out:
#     index State country   latitude   longitude
# 0       2    AK     USA  64.200841 -149.493673
# 1       5    AZ     USA  34.048928 -111.093731
# 2       7    CA     USA  36.778261 -119.417932
# 3      14    GT     USA  34.024545 -118.407284
# 4      16    HI     USA  19.896766 -155.582782
# 5      18    ID     USA  44.068202 -114.742041
# 6      32    MT     USA  46.879682 -110.362566
# 7      39    NV     USA  38.802610 -116.419389
# 8      44    OR     USA  43.804133 -120.554201
# 9      54    UT     USA  39.320980 -111.093731
# 10     58    WA     USA  47.751074 -120.740139

# %% [markdown]
# SQL queries can be passed using read_sql comand to sort the rows i the table

# %%
df = pd.read_sql("SELECT * from data ORDER BY latitude LIMIT 6",con)
df
# Out:
#    index State country   latitude   longitude
# 0     16    HI     USA  19.896766 -155.582782
# 1     12    FL     USA  27.664827  -81.515754
# 2     15    GU     USA  29.526659  -97.936337
# 3     23    LA     USA  31.244823  -92.145025
# 4     53    TX     USA  31.968599  -99.901813
# 5     13    GA     USA  32.157435  -82.907123

# %% [markdown]
# ###Connecting to other kinds of database
# To connect to a MySQL database:

# %%
import MySQLdb
con = MySQLdb.connect(host="localhost", db="test")

# %% [markdown]
# To connect to a PostgreSQL database:

# %%
import psycopg2
con = psycopg2.connect(host="localhost")

# %% [markdown]
# ###Exercises
#
# Write an SQL query via Pandas to insert a new row into the sql table
#
# Write an SQL query via Pandas to drop a table from the sql table
